# %%
import pandas as pd
import warnings

# %%
df = pd.read_csv('behaviour.csv')
df.head(5)
# Out:
#    User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                     393.0
# 1        2       OnePlus 9          Android                     268.0
# 2        3    Xiaomi Mi 11          Android                     154.0
# 3        4  Google Pixel 5          Android                     239.0
# 4        5       iPhone 12              iOS                     187.0
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                   1872.0
# 1                         4.7                   1331.0
# 2                         4.0                    761.0
# 3                         4.8                   1676.0
# 4                         4.3                   1367.0
#
#    Number of Apps Installed  Data Usage (MB/day)   Age  Gender  \
# 0                      67.0               1122.0  40.0    Male
# 1                      42.0                944.0  47.0  Female
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User ID                     700 non-null    int64
#  1   Device Model                698 non-null    object
#  2   Operating System            700 non-null    object
#  3   App Usage Time (min/day)    692 non-null    float64
#  4   Screen On Time (hours/day)  689 non-null    float64
#  5   Battery Drain (mAh/day)     688 non-null    float64
#  6   Number of Apps Installed    687 non-null    float64
#  7   Data Usage (MB/day)         693 non-null    float64
#  8   Age                         690 non-null    float64
#  9   Gender                      700 non-null    object
#  10  User Behavior Class         700 non-null    int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 60.3+ KB

# %%
df.describe()
# Out:
#           User ID  App Usage Time (min/day)  Screen On Time (hours/day)  \
# count  700.000000                692.000000                  689.000000
# mean   342.877143                274.768786                    5.329753
# std    204.528990                177.617612                    3.062285
# min      1.000000                 30.000000                    1.000000
# 25%    168.750000                116.000000                    2.600000
# 50%    339.500000                230.000000                    5.000000
# 75%    512.250000                441.250000                    7.400000
# max    700.000000                598.000000                   12.000000
#
#        Battery Drain (mAh/day)  Number of Apps Installed  Data Usage (MB/day)  \
# count               688.000000                687.000000           693.000000
# mean               1540.902616                 51.305677           946.936508
# std                 816.770905                 26.825584           645.134548
# ...

# %%
df.shape
# Out:
# (700, 11)

# %%
df.columns
# Out:
# Index(['User ID', 'Device Model', 'Operating System',
#        'App Usage Time (min/day)', 'Screen On Time (hours/day)',
#        'Battery Drain (mAh/day)', 'Number of Apps Installed',
#        'Data Usage (MB/day)', 'Age', 'Gender', 'User Behavior Class'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# User ID                        0
# Device Model                   2
# Operating System               0
# App Usage Time (min/day)       8
# Screen On Time (hours/day)    11
# Battery Drain (mAh/day)       12
# Number of Apps Installed      13
# Data Usage (MB/day)            7
# Age                           10
# Gender                         0
# User Behavior Class            0
# dtype: int64

# %%
df[df.duplicated]
# Out:
#      User ID        Device Model Operating System  App Usage Time (min/day)  \
# 258      259        Xiaomi Mi 11          Android                     201.0
# 259      260        Xiaomi Mi 11          Android                     570.0
# 260      261        Xiaomi Mi 11          Android                      64.0
# 261      262           iPhone 12              iOS                     334.0
# 560      364           iPhone 12              iOS                     321.0
# 561      365        Xiaomi Mi 11          Android                     579.0
# 562      366           OnePlus 9          Android                     382.0
# 563      367        Xiaomi Mi 11          Android                     516.0
# 564      368           OnePlus 9          Android                     598.0
# 565      369           OnePlus 9          Android                     102.0
# 566      370           iPhone 12              iOS                     165.0
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [User ID, Device Model, Operating System, App Usage Time (min/day), Screen On Time (hours/day), Battery Drain (mAh/day), Number of Apps Installed, Data Usage (MB/day), Age, Gender, User Behavior Class]
# Index: []

# %% [markdown]
# This means now every duplicates have been dropped.

# %%
df['User Behavior Class'].unique()
# Out:
# array([4, 3, 2, 5, 1], dtype=int64)

# %%
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 8 numerical features : ['User ID', 'App Usage Time (min/day)', 'Screen On Time (hours/day)', 'Battery Drain (mAh/day)', 'Number of Apps Installed', 'Data Usage (MB/day)', 'Age', 'User Behavior Class']
#
# We have 3 categorical features : ['Device Model', 'Operating System', 'Gender']

# %%
for col in categorical_features:
    print(df[col].value_counts(normalize=True)*100)
    print('---------------------------')
# Out:
# Device Model
# Xiaomi Mi 11          20.926756
# Google Pixel 5        20.627803
# iPhone 12             20.627803
# OnePlus 9             19.133034
# Samsung Galaxy S21    18.684604
# Name: proportion, dtype: float64
# ---------------------------
# Operating System
# Android    79.433681
# iOS        20.566319
# Name: proportion, dtype: float64
# ---------------------------
# Gender
# Male      51.862891
# Female    48.137109
# Name: proportion, dtype: float64
# ---------------------------

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(numeric_features)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=df[numeric_features[i]], color='r')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %%
plt.figure(figsize=(20, 15))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
category = [ 'Operating System', 'Device Model']
for i in range(0, len(category)):
    plt.subplot(2, 2, i+1)
    sns.countplot(x=df[category[i]])
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %%
df.head(2)
# Out:
#    User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                     393.0
# 1        2       OnePlus 9          Android                     268.0
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                   1872.0
# 1                         4.7                   1331.0
#
#    Number of Apps Installed  Data Usage (MB/day)   Age  Gender  \
# 0                      67.0               1122.0  40.0    Male
# 1                      42.0                944.0  47.0  Female
#
#    User Behavior Class
# 0                    4
# 1                    3

# %%
df['Device Model'].value_counts().plot.pie(y=df['Device Model'],figsize=(15,16),autopct='%1.1f')
# Out:
# <Axes: ylabel='count'>

# %%
device = pd.DataFrame(df['Device Model'].value_counts())
device.rename(columns = {'Device Model':'Count'},inplace=True)

# %%
device
# Out:
#                     count
# Device Model
# Xiaomi Mi 11          140
# Google Pixel 5        138
# iPhone 12             138
# OnePlus 9             128
# Samsung Galaxy S21    125

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=device.index[:5], y='count',data = device[:5])
plt.title('Top Most Sold Iteams')
plt.xticks(rotation=90)
plt.show()
